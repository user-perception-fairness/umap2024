# %%
import pandas as pd
from scipy.stats import chi2_contingency



# Carregar o arquivo CSV
url = #demographic csv here
df = pd.read_csv(url)

# %%
df.describe()
# Out:
#        experiment_type
# count       430.000000
# mean          2.497674
# std           1.749790
# min           0.000000
# 25%           1.000000
# 50%           2.000000
# 75%           4.000000
# max           5.000000

# %%
# Mapping age ranges to categorical labels
age_mapping = {
    '18-21 anos': '18-21',
    '22-25 anos': '22-25',
    '26-29 anos': '26-29',
    '30-33 anos': '30-33',
    '34-37 anos': '34-37',
    '38-40 anos': '38-40',
    'Mais de 40 anos': 'Mais de 40'
}

df['age_group'] = df['age'].map(age_mapping)

# Now you can use the 'age_group' column for chi-square test
# First, you need to create a contingency table. For example, between 'experiment_type' and 'age_group'
contingency_table = pd.crosstab(df['experiment_type'], df['age_group'])

# Perform the chi-square test
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Output the results
print('Chi-square Statistic:', chi2)
print('P-value:', p)
print('Degrees of Freedom:', dof)
print('Expected Frequencies:', expected)

# Based on the p-value, you can determine if there's a significant association between the groups.


# Create the contingency table
contingency_table = pd.crosstab(df['experiment_type'], df['age'])


print(contingency_table)
# Out:
# Chi-square Statistic: 52.78111399558882
# P-value: 0.006266133657895473
# Degrees of Freedom: 30
# Expected Frequencies: [[11.60930233 24.1255814  15.05581395 13.24186047  7.25581395  3.44651163
#    3.26511628]
#  [10.12093023 21.03255814 13.1255814  11.54418605  6.3255814   3.00465116
#    2.84651163]
#  [10.41860465 21.65116279 13.51162791 11.88372093  6.51162791  3.09302326
#    2.93023256]
#  [ 9.97209302 20.72325581 12.93255814 11.3744186   6.23255814  2.96046512
#    2.80465116]
#  [10.41860465 21.65116279 13.51162791 11.88372093  6.51162791  3.09302326
#    2.93023256]
#  [11.46046512 23.81627907 14.8627907  13.07209302  7.1627907   3.40232558
#    3.22325581]]
# age              18-21 anos  22-25 anos  26-29 anos  30-33 anos  34-37 anos  \
# experiment_type
# 0                        11          30          11          10          11
# 1                         9          18          17           7           5
# 2                        13          23          11          15           3
# 3                         6          20          11          15           9
# 4                         9          26           9          14           6
# 5                        16          16          24          12           6
#
# age              38-40 anos  Mais de 40 anos
# experiment_type
# 0                         5                0
# 1                         3                9
# 2                         2                3
# 3                         4                2
# 4                         2                4
# 5                         3                0

# %%
contingency_table = pd.crosstab(df['experiment_type'], df['gender'])

# Agora, você executa o teste qui-quadrado
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Mostrar os resultados
print("Chi-square Statistic:", chi2)
print("P-value:", p)
print("Degrees of Freedom:", dof)
print("Expected Frequencies:", expected)



#-------

# Create the contingency table
contingency_table = pd.crosstab(df['experiment_type'], df['gender'])


print(contingency_table)
# Out:
# Chi-square Statistic: 9.399216900690627
# P-value: 0.49468119559862234
# Degrees of Freedom: 10
# Expected Frequencies: [[76.18604651  1.63255814  0.18139535]
#  [66.41860465  1.42325581  0.15813953]
#  [68.37209302  1.46511628  0.1627907 ]
#  [65.44186047  1.40232558  0.15581395]
#  [68.37209302  1.46511628  0.1627907 ]
#  [75.20930233  1.61162791  0.17906977]]
# gender           Feminino  Masculino  Outro
# experiment_type
# 0                      78          0      0
# 1                      64          3      1
# 2                      68          2      0
# 3                      66          1      0
# 4                      69          1      0
# 5                      75          2      0

# %%
contingency_table = pd.crosstab(df['experiment_type'], df['education'])

# Executar o teste qui-quadrado
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Exibir os resultados
print(f"Chi-square Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies:")
print(expected)


print(contingency_table)


new_order = [
    'Ensino Médio incompleto',
    'Ensino Médio completo',
    'Ensino superior incompleto',
    'Ensino superior completo',
    'Pós graduação incompleta',
    'Pós graduação completa'
]

contingency_table = contingency_table.reindex(new_order, axis=1)
# Out:
# Chi-square Statistic: 29.081486938621417
# P-value: 0.2605239697376398
# Degrees of Freedom: 25
# Expected Frequencies:
# [[15.05581395  1.26976744 22.49302326 23.7627907  11.42790698  3.99069767]
#  [13.1255814   1.10697674 19.60930233 20.71627907  9.9627907   3.47906977]
#  [13.51162791  1.13953488 20.18604651 21.3255814  10.25581395  3.58139535]
#  [12.93255814  1.09069767 19.32093023 20.41162791  9.81627907  3.42790698]
#  [13.51162791  1.13953488 20.18604651 21.3255814  10.25581395  3.58139535]
#  [14.8627907   1.25348837 22.20465116 23.45813953 11.28139535  3.93953488]]
# education        Ensino Médio completo  Ensino Médio incompleto  \
# experiment_type
# 0                                   19                        0
# 1                                   14                        3
# 2                                   10                        0
# 3                                   14                        0
# 4                                   10                        2
# 5                                   16                        2
#
# education        Ensino superior completo  Ensino superior incompleto  \
# experiment_type
# 0                                      28                          14
# 1                                      18                          23
# 2                                      17                          25
# 3                                      20                          21
# 4                                      21                          24
# 5                                      20                          24
#
# education        Pós graduação completa  Pós graduação incompleta
# experiment_type
# 0                                     9                         8
# 1                                     7                         3
# 2                                    15                         3
# 3                                     8                         4
# 4                                    12                         1
# 5                                    12                         3

# %%
years_of_study = {
    'Ensino Médio incompleto': 10,
    'Ensino Médio completo': 12,
    'Ensino superior incompleto': 14,
    'Ensino superior completo': 16,
    'Pós-graduação incompleta': 18,
    'Pós-graduação completa': 20
}

df['years_of_study'] = df['education'].map(years_of_study)


average_years_by_group = df.groupby('experiment_type')['years_of_study'].mean()

print(average_years_by_group)
# Out:
# experiment_type
# 0    14.295082
# 1    13.931034
# 2    14.269231
# 3    14.218182
# 4    14.245614
# 5    14.000000
# Name: years_of_study, dtype: float64

# %%
contingency_table = pd.crosstab(df['experiment_type'], df['marital status '])



# Executar o teste qui-quadrado
chi2, p, dof, expected = chi2_contingency(contingency_table)

# Exibir os resultados
print(f"Chi-square Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies:")
print(expected)


print(contingency_table)

#-------

contingency_table['Solteiro_Percent'] = (contingency_table['Solteiro(a)'] / contingency_table.sum(axis=1)) * 100

# Vamos exibir apenas a coluna de porcentagem de solteiros
percentage_solteiro = contingency_table['Solteiro_Percent']
print(percentage_solteiro)
# Out:
# Chi-square Statistic: 18.2888507139887
# P-value: 0.5683866783759819
# Degrees of Freedom: 20
# Expected Frequencies:
# [[18.50232558  0.90697674  0.7255814  50.60930233  7.25581395]
#  [16.13023256  0.79069767  0.63255814 44.12093023  6.3255814 ]
#  [16.60465116  0.81395349  0.65116279 45.41860465  6.51162791]
#  [15.89302326  0.77906977  0.62325581 43.47209302  6.23255814]
#  [16.60465116  0.81395349  0.65116279 45.41860465  6.51162791]
#  [18.26511628  0.89534884  0.71627907 49.96046512  7.1627907 ]]
# marital status   Casado(a)  Outro  Separado(a)  Solteiro(a)  União Estável
# experiment_type
# 0                       15      2            1           52              8
# 1                       20      0            1           37             10
# 2                       17      0            0           47              6
# 3                       17      2            0           42              6
# 4                       15      1            0           51              3
# 5                       18      0            2           50              7
# experiment_type
# 0    66.666667
# 1    54.411765
# 2    67.142857
# 3    62.686567
# 4    72.857143
# 5    64.935065
# Name: Solteiro_Percent, dtype: float64

# %%
contingency_table = pd.crosstab(df['experiment_type'], df['movie enthusiast'])


chi2, p, dof, expected = chi2_contingency(contingency_table)

print(f"Chi-square Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies:")
print(expected)


print(contingency_table)
# Out:
# Chi-square Statistic: 25.024960507519317
# P-value: 0.7238179407225658
# Degrees of Freedom: 30
# Expected Frequencies:
# [[26.48372093 16.68837209 16.14418605  1.26976744  3.62790698  1.45116279
#   12.33488372]
#  [23.08837209 14.54883721 14.0744186   1.10697674  3.1627907   1.26511628
#   10.75348837]
#  [23.76744186 14.97674419 14.48837209  1.13953488  3.25581395  1.30232558
#   11.06976744]
#  [22.74883721 14.33488372 13.86744186  1.09069767  3.11627907  1.24651163
#   10.59534884]
#  [23.76744186 14.97674419 14.48837209  1.13953488  3.25581395  1.30232558
#   11.06976744]
#  [26.14418605 16.4744186  15.9372093   1.25348837  3.58139535  1.43255814
#   12.17674419]]
# movie enthusiast  Concordo Moderadamente  Concordo Pouco  Concordo Totalmente  \
# experiment_type
# 0                                     23              20                   13
# 1                                     17              14                   15
# 2                                     25              18                   14
# 3                                     28              12                   12
# 4                                     28              13                   16
# 5                                     25              15                   19
#
# movie enthusiast  Discordo Moderadamente  Discordo Pouco  Discordo Totalmente  \
# experiment_type
# 0                                      2               3                    2
# 1                                      2               6                    4
# 2                                      1               1                    0
# 3                                      1               4                    1
# 4                                      0               2                    0
# 5                                      1               4                    1
#
# movie enthusiast  Nem Concordo, Nem Discordo
# experiment_type
# 0                                         15
# 1                                         10
# 2                                         11
# 3                                          9
# 4                                         11
# 5                                         12

# %%
likert_scale = {
    'Concordo Totalmente': 7,
    'Concordo Moderadamente': 6,
    'Concordo Pouco': 5,
    'Nem Concordo, Nem Discordo': 4,
    'Discordo Pouco': 3,
    'Discordo Moderadamente': 2,
    'Discordo Totalmente': 1
}

# Mapear as respostas para valores numéricos
df['enthusiast_score'] = df['movie enthusiast'].map(likert_scale)

# Calcular a média para cada 'experiment_type'
average_scores = df.groupby('experiment_type')['enthusiast_score'].mean()

print(average_scores)
# Out:
# experiment_type
# 0    5.179487
# 1    5.044118
# 2    5.528571
# 3    5.417910
# 4    5.642857
# 5    5.467532
# Name: enthusiast_score, dtype: float64

# %%
contingency_table = pd.crosstab(df['experiment_type'], df['trust'])


chi2, p, dof, expected = chi2_contingency(contingency_table)

print(f"Chi-square Statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of Freedom: {dof}")
print("Expected Frequencies:")
print(expected)


print(contingency_table)
# Out:
# Chi-square Statistic: 33.58332224452476
# P-value: 0.2977954985012616
# Degrees of Freedom: 30
# Expected Frequencies:
# [[30.29302326 18.86511628 15.9627907   0.90697674  4.17209302  1.26976744
#    6.53023256]
#  [26.40930233 16.44651163 13.91627907  0.79069767  3.6372093   1.10697674
#    5.69302326]
#  [27.18604651 16.93023256 14.3255814   0.81395349  3.74418605  1.13953488
#    5.86046512]
#  [26.02093023 16.20465116 13.71162791  0.77906977  3.58372093  1.09069767
#    5.60930233]
#  [27.18604651 16.93023256 14.3255814   0.81395349  3.74418605  1.13953488
#    5.86046512]
#  [29.90465116 18.62325581 15.75813953  0.89534884  4.11860465  1.25348837
#    6.44651163]]
# trust            Concordo Moderadamente  Concordo Pouco  Concordo Totalmente  \
# experiment_type
# 0                                    30              17                   15
# 1                                    24              21                    9
# 2                                    27              18                   16
# 3                                    28              18                   16
# 4                                    33               7                   17
# 5                                    25              23                   15
#
# trust            Discordo Moderadamente  Discordo Pouco  Discordo Totalmente  \
# experiment_type
# 0                                     3               3                    2
# 1                                     1               2                    2
# 2                                     0               4                    1
# 3                                     0               2                    0
# 4                                     0               6                    2
# 5                                     1               6                    0
#
# trust            Nem Concordo, Nem Discordo
# experiment_type
# 0                                         8
# 1                                         9
# 2                                         4
# 3                                         3
# 4                                         5
# 5                                         7

# %%
likert_scale = {
    'Concordo Totalmente': 7,
    'Concordo Moderadamente': 6,
    'Concordo Pouco': 5,
    'Nem Concordo, Nem Discordo': 4,
    'Discordo Pouco': 3,
    'Discordo Moderadamente': 2,
    'Discordo Totalmente': 1
}

df['trust_score'] = df['trust'].map(likert_scale)

average_scores = df.groupby('experiment_type')['trust_score'].mean()

print(average_scores)
# Out:
# experiment_type
# 0    5.371795
# 1    5.264706
# 2    5.614286
# 3    5.791045
# 4    5.600000
# 5    5.428571
# Name: trust_score, dtype: float64
